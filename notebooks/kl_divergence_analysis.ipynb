# %% [markdown]
# # KL Divergence Analysis for RHVAE
#
# This notebook provides a step-by-step analysis of the KL divergence issue in the RHVAE model using the exact experimental parameters.
#
# ## Experimental Context
#
# Command used:
# ```bash
# python /scratch/alaforgu/longitudinal_experiments/RlVAE/run_experiment.py \
#     experiment=global_vanilla_rlvae_pipeline \
#     model=rhvae_original_with_metric_update \
#     data=cyclic_sprites \
#     model.latent_dim=16 \
#     experiment.skip_stage1=true \
#     experiment.stage2.epochs=30 \
#     experiment.stage2.visualization=minimal \
#     pretrained.encoder_path=data/pretrained/encoder_diverse_mlp_ld16_20250820_112008.pt \
#     pretrained.decoder_path=data/pretrained/decoder_diverse_mlp_ld16_20250820_112008.pt \
#     pretrained.metric_path=data/pretrained/metric_diverse_mlp_ld16_20250820_112010.pt \
#     model.metric_update_frequency=47 \
#     data.num_workers=0 \
#     training.data.num_workers=0 \
#     --multirun
# ```

# %%
# !python /scratch/alaforgu/longitudinal_experiments/RlVAE/run_experiment.py \
    experiment=global_vanilla_rlvae_pipeline \
    model=rhvae_original_with_metric_update \
    data=cyclic_sprites \
    model.latent_dim=16 \
    experiment.skip_stage1=true \
    experiment.stage2.epochs=30 \
    experiment.stage2.visualization=minimal \
    pretrained.encoder_path=data/pretrained/encoder_diverse_mlp_ld16_20250820_112008.pt \
    pretrained.decoder_path=data/pretrained/decoder_diverse_mlp_ld16_20250820_112008.pt \
    pretrained.metric_path=data/pretrained/metric_diverse_mlp_ld16_20250820_112010.pt \
    model.metric_update_frequency=47 \
    data.num_workers=0 \
    training.data.num_workers=0 \
    --multirun
# Out:
# [2025-08-27 12:10:44,760][HYDRA] Launching 1 jobs locally
# [2025-08-27 12:10:44,760][HYDRA] 	#0 : experiment=global_vanilla_rlvae_pipeline model=rhvae_original_with_metric_update data=cyclic_sprites model.latent_dim=16 experiment.skip_stage1=True experiment.stage2.epochs=30 experiment.stage2.visualization=minimal pretrained.encoder_path=data/pretrained/encoder_diverse_mlp_ld16_20250820_112008.pt pretrained.decoder_path=data/pretrained/decoder_diverse_mlp_ld16_20250820_112008.pt pretrained.metric_path=data/pretrained/metric_diverse_mlp_ld16_20250820_112010.pt model.metric_update_frequency=47 data.num_workers=0 training.data.num_workers=0
# 🧠 RlVAE Experiment Runner with Hydra
# ==================================================
# 📋 Configuration:
# model:
#   _target_: original_rlvae.src.models.riemannian_flow_vae.RiemannianFlowVAE
#   latent_dim: 16
#   input_dim:
#   - 64
#   - 64
#   - 3
#   architecture: mlp
#   encoder:
#     architecture: mlp
#   n_flows: 4
#   flow_type: planar
#   flow_hidden_dims:
#   - 64
#   - 64
#   beta: 1.0
#   riemannian_beta: 1.0
#   loop_lambda: 0.05
#   posterior_type: riemannian_metric
#   riemannian_kl_mode: centered
#   learn_mu_prior: false
#   metric:
#     start_with_identity: false
#     n_centroids: 10
#     temperature: 0.5
#     regularization: 0.01
#   update_metric_during_training: false
#   metric_update_frequency: 47
#   metric_update_alpha: 0.01
#   metric_update_temperature: 0.1
#   metric_update_regularization: 0.01
#   adaptive_kl_enabled: true
#   adaptive_kl_ramp_up_steps: 10
#   adaptive_kl_alignment_weight: 0.1
#   pretrained:
#     encoder_path: null
#     decoder_path: null
#     metric_path: null
# training:
#   trainer:
#     max_epochs: 200
#     accelerator: gpu
#     devices: 1
#     strategy: auto
#     precision: 16-mixed
#     log_every_n_steps: 5
#     val_check_interval: 0.5
#     num_sanity_val_steps: 2
#     enable_progress_bar: true
#     enable_model_summary: true
#     deterministic: false
#     use_distributed_sampler: false
#   data:
#     batch_size: 64
#     num_workers: 0
#     pin_memory: true
#   model:
#     latent_dim: 16
#     beta: 1.0
#     riemannian_beta: 8.0
#     posterior:
#       type: riemannian_metric
#     sampling:
#       method: geodesic
#       use_riemannian: true
#     loop:
#       mode: open
#       penalty: 0.0
#   optimizer:
#     name: adam
#     lr: 0.001
#     weight_decay: 0.0001
#   logging:
#     log_every_n_steps: 10
#     save_top_k: 3
#     monitor: val_loss
#     mode: min
#   visualization:
#     frequency: 10
#     level: standard
#   n_train_samples: 5000
#   n_val_samples: 888
#   scheduler:
#     mode: min
#     factor: 0.8
#     patience: 5
#     threshold: 0.01
#     min_lr: 1.0e-07
#   early_stopping:
#     patience: 30
#     monitor: val_loss
#     mode: min
#     min_delta: 0.001
# data:
#   train_path: data/processed/Sprites_train_cyclic.pt
#   test_path: data/processed/Sprites_test_cyclic.pt
#   train_meta_path: data/processed/Sprites_train_cyclic_metadata.pt
#   test_meta_path: data/processed/Sprites_test_cyclic_metadata.pt
#   sequence_length: 8
#   image_size:
#   - 64
#   - 64
#   channels: 3
#   num_workers: 0
#   pin_memory: true
#   persistent_workers: true
#   max_train_samples: 24000
#   max_test_samples: 1000
#   verify_cyclicity: true
#   cyclicity_threshold: 0.01
# visualization:
#   level: minimal
#   frequency: 5
#   enable_basic: true
#   enable_manifold: false
#   enable_interactive: false
#   enable_flow_analysis: false
#   basic_frequency: 5
#   manifold_frequency: 10
#   interactive_frequency: 20
#   flow_frequency: 10
#   disable_curvature: true
#   max_sequences: 4
#   enable_fancy_plots: false
#   save_local: false
#   log_to_wandb: true
# evaluation:
#   enabled: true
#   run_during_training: false
#   run_during_testing: true
#   run_at_end_only: true
#   fid:
#     enabled: true
#     compute_fid: true
#     n_generated_samples: 1000
#     batch_size: 50
#     inception_batch_size: 64
#     real_samples_subset: 2000
#     cache_real_stats: true
#     fid_cache_dir: data/fid_cache
#     fid_batch_size: 32
#     real_data_cache_key: test_dataset
#     n_real_samples: 1000
#   generation:
#     enabled: true
#     methods:
#     - geodesic
#     - enhanced
#     - basic
#     n_samples_per_method: 100
#     comprehensive_n_samples: 500
#     batch_size: 32
#     save_samples: true
#   generation_methods:
#   - geodesic
#   - enhanced
#   - basic
#   sampler_types:
#   - working
#   reconstruction:
#     enabled: true
#     n_test_samples: 200
#     metrics:
#     - mse
#     - psnr
#     - ssim
#     - l1
#     save_reconstructions: false
#   inference:
#     enabled: true
#     n_samples: 100
#     analyze_geometry: true
#     compute_effective_dim: true
#   benchmarking:
#     enabled: false
#     generation_trials: 5
#     inference_trials: 5
#   output:
#     save_detailed_results: true
#     log_to_wandb: true
#     create_summary_plot: true
#     save_generated_grid: true
#   memory:
#     max_batch_size: 64
#     enable_cleanup: true
#     use_cpu_offload: false
#   frequency:
#     every_n_epochs: 5
#     at_epochs: []
#     min_epoch: 10
# metric:
#   name: rhvae
#   implementation: rhvae
#   temperature: 0.7
#   regularization: 0.01
#   n_centroids: 50
#   centroid_method: kmedoids
#   neighbor_mode: global
#   knn_k: 300
#   log_heatmaps: 6
# sampling:
#   enabled: true
#   method: rhmc
#   n_steps: 100
#   n_leapfrog: 50
#   step_size: 0.001
#   log_acceptance_rate: true
#   log_energy: true
# checkpoint:
#   save: true
#   load: false
#   dir: outputs/checkpoints
#   metric_dir: ${output_dir}/metrics
#   stageA_dir: ${output_dir}/stageA
#   stageB_dir: ${output_dir}/stageB
#   stageC_dir: ${output_dir}/stageC
#   stageA_model: stageA_vae.pt
#   metric_file: metric_t${metric.temperature}.pt
#   rhmc_samples: rhmc_samples_t0.pt
# experiment:
#   skip_stage1: true
#   type: pipeline
#   name: global_vanilla_rlvae_pipeline
#   description: 'Full pipeline: vanilla VAE with diverse metric extraction, then RLVAE
#     with loaded components.'
#   stage1:
#     batch_size: 64
#     model: vanilla_vae
#     training:
#       full_data:
#         batch_size: 64
#     data: ${data}
#     visualization: minimal
#     extract_diverse_metric: true
#     architecture: ${model.encoder.architecture}
#     latent_dim: ${model.latent_dim}
#     sequence_length: ${data.sequence_length}
#     n_flows: ${oc.decode:${data.sequence_length} - 1}
#     beta: ${model.beta}
#     flow_hidden_dims: ${model.flow_hidden_dims}
#     flow_type: ${model.flow_type}
#     epochs: 200
#     temperature: 0.5
#     regularization: 0.01
#     preset: balanced
#     n_heatmaps: 6
#   stage2:
#     batch_size: 64
#     model: mlp_rlvae
#     training:
#       full_data:
#         batch_size: 64
#     data: ${data}
#     visualization: minimal
#     epochs: 30
#     load_pretrained_from_stage1: true
#     sampling:
#       use_riemannian: true
#     posterior:
#       type: riemannian_metric
#     architecture: ${model.encoder.architecture}
#     latent_dim: ${model.latent_dim}
#     sequence_length: ${data.sequence_length}
#     n_flows: ${oc.decode:${data.sequence_length} - 1}
#     beta: ${model.beta}
#     flow_hidden_dims: ${model.flow_hidden_dims}
#     flow_type: ${model.flow_type}
#     riemannian_beta: ${model.riemannian_beta}
#     metric:
#       metric_reg_weight: 0.0
#   log_level: INFO
#   log_to_file: true
#   deterministic: true
#   benchmark: false
#   visualization:
#     sequence_viz_count: 64
#     cluster_sequences: true
#     n_clusters: 5
#     cluster_coloring: true
#     show_cluster_centroids: true
#   batch_size: 64
# experiment_name: rlvae_comparison
# project_name: rlvae-hyperparameter-optimization
# description: Systematic comparison of Riemannian geometry effects on VAE latent spaces
#   with hyperparameter optimization
# seed: 42
# device: auto
# output_dir: outputs
# wandb:
#   project: rlvae-three-stage-visuals
#   entity: null
#   mode: online
#   tags: []
#   group: null
#   pipeline_mode: per_stage
#   artifacts:
#     enabled: true
#     namespace: rlvae
#     aliases:
#       stage_a_latest: stageA_latest
#       stage_b_latest: stageB_latest
#       stage_c_latest: stageC_latest
# pretrained:
#   encoder_path: data/pretrained/encoder_diverse_mlp_ld16_20250820_112008.pt
#   decoder_path: data/pretrained/decoder_diverse_mlp_ld16_20250820_112008.pt
#   metric_path: data/pretrained/metric_diverse_mlp_ld16_20250820_112010.pt
#
# [HYDRA DEBUG] config.model.metric: start_with_identity: false
# n_centroids: 10
# temperature: 0.5
# regularization: 0.01
#
# 🚀 RlVAE Experiment Runner
# 📅 Experiment: rlvae_comparison
# 💻 Device: cuda
# 📁 Output: outputs
# Seed set to 42
# 🎲 Seed: 42
#
# 🧪 Running pipeline experiment: global_vanilla_rlvae_pipeline
# ⏭️ Skipping Stage 1 (vanilla VAE) as requested by experiment.skip_stage1=true
#
# === [Pipeline] Stage 2: RLVAE Training ===
# [PATCH] OmegaConf.resolve failed: cannot access local variable 'OmegaConf' where it is not associated with a value
# [PATCH] Set self.config.model.riemannian_beta = 1.0
# [PATCH] Coerced stage2.n_flows expression to int: 7
# [PATCH] Set self.config.model.n_flows = 7
# Error executing job with overrides: ['experiment=global_vanilla_rlvae_pipeline', 'model=rhvae_original_with_metric_update', 'data=cyclic_sprites', 'model.latent_dim=16', 'experiment.skip_stage1=True', 'experiment.stage2.epochs=30', 'experiment.stage2.visualization=minimal', 'pretrained.encoder_path=data/pretrained/encoder_diverse_mlp_ld16_20250820_112008.pt', 'pretrained.decoder_path=data/pretrained/decoder_diverse_mlp_ld16_20250820_112008.pt', 'pretrained.metric_path=data/pretrained/metric_diverse_mlp_ld16_20250820_112010.pt', 'model.metric_update_frequency=47', 'data.num_workers=0', 'training.data.num_workers=0']
# Traceback (most recent call last):
#   File "/scratch/alaforgu/longitudinal_experiments/RlVAE/run_experiment.py", line 2253, in main
#     runner.run()
#   File "/scratch/alaforgu/longitudinal_experiments/RlVAE/run_experiment.py", line 137, in run
#     self.run_pipeline_experiment()
#   File "/scratch/alaforgu/longitudinal_experiments/RlVAE/run_experiment.py", line 609, in run_pipeline_experiment
#     raw_data = torch.load(self.config.data.train_path, map_location='cpu')
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/alaforgu/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 1479, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/alaforgu/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 759, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/alaforgu/miniconda3/lib/python3.12/site-packages/torch/serialization.py", line 740, in __init__
#     super().__init__(open(name, mode))
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'data/processed/Sprites_train_cyclic.pt'
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
